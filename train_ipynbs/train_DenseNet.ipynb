# %%
# origin
# TRAIN_CLASSIFY_LEARNING_RATE = 1e-4

# DENSE_NET_BLOCKS = 3
# DENSE_NET_BLOCK_LAYERS = 5
# DENSE_NET_INITIAL_CONV_DIM = 16
# DENSE_NET_GROWTH_RATE = DENSE_NET_INITIAL_CONV_DIM // 2
# # called DenseNet-BC if ENABLE_BOTTLENETCK and COMPRESSION < 1 in paper
# DENSE_NET_ENABLE_BOTTLENETCK = False
# DENSE_NET_TRANSITION_COMPRESSION = 1.0
# DENSE_NET_ENABLE_DROPOUT = False
# DENSE_NET_DROPOUT = 0.5

# Total params: 250,946
# Trainable params: 248,786
# Non-trainable params: 2,160
# ____________________________________________________________________________________________________
# classify train round DenseNet-17-15
# Epoch 1/100000000
# Epoch 00000: val_loss improved from inf to 0.48308, saving model to /output/training_logs/classify-run-DenseNet-17-15/checkpoint-00-0.4831.hdf5
# 336s - loss: 0.4032 - acc: 0.8438 - val_loss: 0.4831 - val_acc: 0.7500
# Epoch 2/100000000
# Epoch 00001: val_loss did not improve
# 247s - loss: 0.2807 - acc: 0.8500 - val_loss: 0.5616 - val_acc: 0.7500
# Epoch 3/100000000
# Epoch 00002: val_loss did not improve
# 224s - loss: 0.2225 - acc: 0.9062 - val_loss: 0.6071 - val_acc: 0.7188
# Epoch 4/100000000
# Epoch 00003: val_loss did not improve
# 225s - loss: 0.2288 - acc: 0.9125 - val_loss: 0.5929 - val_acc: 0.7500
# Epoch 5/100000000
# Epoch 00004: val_loss improved from 0.48308 to 0.48113, saving model to /output/training_logs/classify-run-DenseNet-17-15/checkpoint-04-0.4811.hdf5
# 237s - loss: 0.2387 - acc: 0.8812 - val_loss: 0.4811 - val_acc: 0.7500
# Epoch 6/100000000
# Epoch 00005: val_loss improved from 0.48113 to 0.45616, saving model to /output/training_logs/classify-run-DenseNet-17-15/checkpoint-05-0.4562.hdf5
# 210s - loss: 0.2341 - acc: 0.9000 - val_loss: 0.4562 - val_acc: 0.7812
# Epoch 7/100000000
# Epoch 00006: val_loss improved from 0.45616 to 0.32753, saving model to /output/training_logs/classify-run-DenseNet-17-15/checkpoint-06-0.3275.hdf5
# 230s - loss: 0.2135 - acc: 0.8812 - val_loss: 0.3275 - val_acc: 0.7500
# Epoch 8/100000000
# Epoch 00007: val_loss did not improve
# 217s - loss: 0.2137 - acc: 0.9062 - val_loss: 0.3623 - val_acc: 0.8438
# Epoch 9/100000000
# Epoch 00008: val_loss did not improve
# 227s - loss: 0.3164 - acc: 0.8438 - val_loss: 0.3411 - val_acc: 0.8438
# Epoch 10/100000000
# Epoch 00009: val_loss did not improve
# 253s - loss: 0.2175 - acc: 0.8812 - val_loss: 0.3398 - val_acc: 0.8750
# Epoch 11/100000000
# Epoch 00010: val_loss did not improve
# 229s - loss: 0.1724 - acc: 0.9250 - val_loss: 0.4172 - val_acc: 0.7500
# Epoch 12/100000000

# %%
# TRAIN_CLASSIFY_LEARNING_RATE = 1e-5
# DENSE_NET_ENABLE_DROPOUT = True
# new randomized position, OK...

# Total params: 250,946
# Trainable params: 248,786
# Non-trainable params: 2,160
# ____________________________________________________________________________________________________
# classify train round DenseNet-18-0
# Epoch 1/100000000
#  9/10 [==========================>...] - ETA: 16s - loss: 1.8258 - acc: 0.3333Epoch 00000: val_loss improved from inf to 0.81970, saving model to /output/training_logs/classify-run-DenseNet-18-0/checkpoint-00-0.8197.hdf5
# 10/10 [==============================] - 272s - loss: 1.7737 - acc: 0.3375 - val_loss: 0.8197 - val_acc: 0.2500
# Epoch 2/100000000
#  9/10 [==========================>...] - ETA: 10s - loss: 1.4111 - acc: 0.4306Epoch 00001: val_loss improved from 0.81970 to 0.64727, saving model to /output/training_logs/classify-run-DenseNet-18-0/checkpoint-01-0.6473.hdf5
# 10/10 [==============================] - 215s - loss: 1.4293 - acc: 0.4375 - val_loss: 0.6473 - val_acc: 0.7188
# Epoch 3/100000000
#  9/10 [==========================>...] - ETA: 10s - loss: 0.9344 - acc: 0.5417Epoch 00002: val_loss improved from 0.64727 to 0.51688, saving model to /output/training_logs/classify-run-DenseNet-18-0/checkpoint-02-0.5169.hdf5
# 10/10 [==============================] - 230s - loss: 0.8957 - acc: 0.5500 - val_loss: 0.5169 - val_acc: 0.7500
# Epoch 4/100000000
#  9/10 [==========================>...] - ETA: 11s - loss: 0.7690 - acc: 0.6597Epoch 00003: val_loss did not improve
# 10/10 [==============================] - 214s - loss: 0.7218 - acc: 0.6875 - val_loss: 0.5169 - val_acc: 0.7500
# Epoch 5/100000000
#  9/10 [==========================>...] - ETA: 13s - loss: 0.5940 - acc: 0.7569Epoch 00004: val_loss improved from 0.51688 to 0.48428, saving model to /output/training_logs/classify-run-DenseNet-18-0/checkpoint-04-0.4843.hdf5
# 10/10 [==============================] - 240s - loss: 0.5911 - acc: 0.7500 - val_loss: 0.4843 - val_acc: 0.7500
# Epoch 6/100000000
#  9/10 [==========================>...] - ETA: 10s - loss: 0.6249 - acc: 0.7431Epoch 00005: val_loss improved from 0.48428 to 0.46407, saving model to /output/training_logs/classify-run-DenseNet-18-0/checkpoint-05-0.4641.hdf5
# 10/10 [==============================] - 203s - loss: 0.6309 - acc: 0.7625 - val_loss: 0.4641 - val_acc: 0.7500
# Epoch 7/100000000
#  9/10 [==========================>...] - ETA: 11s - loss: 0.5236 - acc: 0.7917Epoch 00006: val_loss did not improve
# 10/10 [==============================] - 225s - loss: 0.5697 - acc: 0.7688 - val_loss: 0.5044 - val_acc: 0.7500
# Epoch 8/100000000
#  9/10 [==========================>...] - ETA: 12s - loss: 0.5042 - acc: 0.7847Epoch 00007: val_loss improved from 0.46407 to 0.43801, saving model to /output/training_logs/classify-run-DenseNet-18-0/checkpoint-07-0.4380.hdf5
# 10/10 [==============================] - 248s - loss: 0.5277 - acc: 0.7750 - val_loss: 0.4380 - val_acc: 0.7500
# Epoch 9/100000000
#  9/10 [==========================>...] - ETA: 12s - loss: 0.5038 - acc: 0.7778Epoch 00008: val_loss did not improve
# 10/10 [==============================] - 235s - loss: 0.4823 - acc: 0.7937 - val_loss: 0.4392 - val_acc: 0.7500
# Epoch 10/100000000
#  9/10 [==========================>...] - ETA: 11s - loss: 0.5139 - acc: 0.8125Epoch 00009: val_loss improved from 0.43801 to 0.43669, saving model to /output/training_logs/classify-run-DenseNet-18-0/checkpoint-09-0.4367.hdf5
# 10/10 [==============================] - 223s - loss: 0.5109 - acc: 0.8063 - val_loss: 0.4367 - val_acc: 0.7500
# Epoch 11/100000000
#  9/10 [==========================>...] - ETA: 11s - loss: 0.5162 - acc: 0.7847Epoch 00010: val_loss improved from 0.43669 to 0.39716, saving model to /output/training_logs/classify-run-DenseNet-18-0/checkpoint-10-0.3972.hdf5
# 10/10 [==============================] - 227s - loss: 0.5097 - acc: 0.7875 - val_loss: 0.3972 - val_acc: 0.7500
# Epoch 12/100000000
#  9/10 [==========================>...] - ETA: 12s - loss: 0.5201 - acc: 0.7986Epoch 00011: val_loss did not improve
# 10/10 [==============================] - 237s - loss: 0.5191 - acc: 0.7937 - val_loss: 0.4293 - val_acc: 0.7500
# Epoch 13/100000000
#  9/10 [==========================>...] - ETA: 11s - loss: 0.5646 - acc: 0.7708Epoch 00012: val_loss improved from 0.39716 to 0.29600, saving model to /output/training_logs/classify-run-DenseNet-18-0/checkpoint-12-0.2960.hdf5
# 10/10 [==============================] - 235s - loss: 0.6063 - acc: 0.7625 - val_loss: 0.2960 - val_acc: 0.7812
# Epoch 14/100000000
#  9/10 [==========================>...] - ETA: 11s - loss: 0.4012 - acc: 0.8125Epoch 00013: val_loss did not improve
# 10/10 [==============================] - 243s - loss: 0.4475 - acc: 0.8000 - val_loss: 0.3330 - val_acc: 0.8438
# Epoch 15/100000000
#  1/10 [==>...........................] - ETA: 3s - loss: 0.7420 - acc: 0.6250
# /usr/local/lib/python3.5/dist-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.567578). Check your callbacks.
#   % delta_t_median)
#  9/10 [==========================>...] - ETA: 12s - loss: 0.5946 - acc: 0.7361Epoch 00014: val_loss did not improve
# 10/10 [==============================] - 257s - loss: 0.5880 - acc: 0.7375 - val_loss: 0.3863 - val_acc: 0.7500
# Epoch 16/100000000
#  9/10 [==========================>...] - ETA: 13s - loss: 0.3841 - acc: 0.8681Epoch 00015: val_loss improved from 0.29600 to 0.24742, saving model to /output/training_logs/classify-run-DenseNet-18-0/checkpoint-15-0.2474.hdf5

# %%
# debug record idx msg
# TRAIN_CLASSIFY_LEARNING_RATE = 3e-6
# continue to explore as below

# %%
from train_classification import classify_train
classify_train()
# Out:
# Using TensorFlow backend.
# get meta_dict from cache
# tumor record size (975, 12)
# tumor_records_train randomized
# after resample, got 2510 samples
# start classify_train
# input
# (?, 32, 32, 32, 16)
# dense block
# (?, 32, 32, 32, 16)
# (?, 32, 32, 32, 24)
# (?, 32, 32, 32, 32)
# (?, 32, 32, 32, 40)
# (?, 32, 32, 32, 48)
# (?, 32, 32, 32, 56)
# transition block
# (?, 32, 32, 32, 56)
# (?, 16, 16, 16, 56)
# dense block
# (?, 16, 16, 16, 56)
# (?, 16, 16, 16, 64)
# (?, 16, 16, 16, 72)
# (?, 16, 16, 16, 80)
# (?, 16, 16, 16, 88)
# (?, 16, 16, 16, 96)
# transition block
# (?, 16, 16, 16, 96)
# (?, 8, 8, 8, 96)
# dense block
# (?, 8, 8, 8, 96)
# (?, 8, 8, 8, 104)
# (?, 8, 8, 8, 112)
# (?, 8, 8, 8, 120)
# (?, 8, 8, 8, 128)
# (?, 8, 8, 8, 136)
# top
# (?, 136)
# (?, 2)
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
